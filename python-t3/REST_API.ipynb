# %%
import requests,json

# %%
API_keys="88a42563dca0a0ca5fa22c2144898c1e"
city_name="Junagadh"
url=f"http://api.openweathermap.org/geo/1.0/direct?q={city_name}&appid={API_keys}"
response=requests.get(url)
response.status_code
result=response.json()
result
# Out:
# [{'name': 'Junagadh',
#   'local_names': {'ml': 'ജുനാഗഡ്',
#    'te': 'జునాగఢ్',
#    'he': "ג'ונגאד",
#    'mr': 'जुनागड',
#    'gu': 'જુનાગઢ',
#    'ar': 'جوناغاد',
#    'ta': 'ஜூனாகத்',
#    'bn': 'জুনাগড়',
#    'hi': 'जूनागढ़',
#    'ur': 'جونا گڑھ',
#    'tr': 'Cünâgerh',
#    'ja': 'ジュナーガド',
#    'kn': 'ಜುನಗದ್'},
#   'lat': 21.5220416,
#   'lon': 70.4582458,
#   'country': 'IN',
#   'state': 'Gujarat'}]

# %%
lat=result[0]['lat']
lon=result[0]['lon']
print(lat,lon)
# Out:
# 21.5220416 70.4582458

# %%
url=f"http://api.openweathermap.org/data/2.5/air_pollution?lat={lat}&lon={lon}&appid={API_keys}"
response=requests.get(url)
print(response.status_code)
result=response.json()
print(json.dumps(result,indent=3))
# Out:
# 200
# {
#    "coord": {
#       "lon": 70.4582,
#       "lat": 21.522
#    },
#    "list": [
#       {
#          "main": {
#             "aqi": 3
#          },
#          "components": {
#             "co": 75.51,
#             "no": 0.01,
#             "no2": 0.04,
#             "o3": 37.82,
#             "so2": 0.22,
#             "pm2_5": 10.38,
#             "pm10": 55.82,
#             "nh3": 0
#          },
#          "dt": 1780468919
#       }
#    ]
# }

# %%
aqi=result['list'][0]['main']['aqi']
co=result['list'][0]['components']['co']
no=result['list'][0]['components']['no']
no2=result['list'][0]['components']['no2']
co=result['list'][0]['components']['co']
o3=result['list'][0]['components']['o3']
so2=result['list'][0]['components']['so2']
pm2_5=result['list'][0]['components']['pms_5']
pm10=result['list'][0]['components']['pm10']
nh3=result['list'][0]['components']['nh3']

print(aqi,"aqi")
print(no,'no')
print(no2,'no2')
print(co,"co")
print(o3,'o3')
print(so2,'so2')
print(pm10,'pm10')
# Out:
# 3 aqi
# 0.01 no
# 0.04 no2
# 75.51 co
# 37.82 o3
# 0.22 so2
# 55.82 pm10

# %%
import pandas as pd

# %%
d={'aqi':[],'co':[],'o3':[],'no':[],'no2':[],'so2':[],'pm10':[],'pm2_5':[],'nh3':[]}

# %%
url2=f"http://api.openweathermap.org/data/2.5/air_pollution/forecast?lat={lat}&lon={lon}&appid={API_keys}"
response=requests.get(url2)
print(response.status_code)
result=response.json()
print(json.dumps(result,indent=3))
# Out:
# 200
# {
#    "coord": {
#       "lon": 70.4582,
#       "lat": 21.522
#    },
#    "list": [
#       {
#          "main": {
#             "aqi": 3
#          },
#          "components": {
#             "co": 75.51,
#             "no": 0.01,
#             "no2": 0.04,
#             "o3": 37.82,
#             "so2": 0.22,
#             "pm2_5": 10.38,
#             "pm10": 55.82,
#             "nh3": 0
#          },
#          "dt": 1780470000
#       },
#       {
#          "main": {
#             "aqi": 3
#          },
#          "components": {
#             "co": 75.7,
#             "no": 0.01,
#             "no2": 0.04,
#             "o3": 37.78,
#             "so2": 0.21,
#             "pm2_5": 10.53,
#             "pm10": 56.91,
#             "nh3": 0
#          },
#          "dt": 1780473600
#       },
#       {
#          "main": {
#             "aqi": 3
#          },
#          "components": {
#             "co": 75.8,
#             "no": 0.01,
#             "no2": 0.04,
# ...

# %%
for i in result['list']:
    d['aqi']=i['main']['aqi']
    d['co'].append(i['components']['co'])
    d['o3'].append(i['components']['o3'])
    d['no'].append(i['components']['no'])
    d['no2'].append(i['components']['no2'])
    d['so2'].append(i['components']['so2'])
    d['pm10'].append(i['components']['pm10'])
    d['pm2_5'].append(i['components']['pm2_5'])
    d['nh3'].append(i['components']['nh3'])
df=pd.DataFrame(data=d)
df.head()
# Out:
#    aqi     co     o3    no   no2   so2   pm10  pm2_5  nh3
# 0    4  75.51  37.82  0.01  0.04  0.22  55.82  10.38    0
# 1    4  75.70  37.78  0.01  0.04  0.21  56.91  10.53    0
# 2    4  75.80  37.85  0.01  0.04  0.21  57.64  10.68    0
# 3    4  76.25  38.12  0.01  0.04  0.21  57.95  10.79    0
# 4    4  76.36  38.42  0.01  0.04  0.21  57.48  10.76    0

# %%
url3=f"https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid={API_keys}"
response=requests.get(url3)
print(response.status_code)
result=response.json()
print(json.dumps(result,indent=3))
# Out:
# 200
# {
#    "coord": {
#       "lon": 70.4582,
#       "lat": 21.522
#    },
#    "weather": [
#       {
#          "id": 800,
#          "main": "Clear",
#          "description": "clear sky",
#          "icon": "01d"
#       }
#    ],
#    "base": "stations",
#    "main": {
#       "temp": 310.34,
#       "feels_like": 314.77,
#       "temp_min": 310.34,
#       "temp_max": 310.34,
#       "pressure": 1005,
#       "humidity": 40,
#       "sea_level": 1005,
#       "grnd_level": 993
#    },
#    "visibility": 10000,
#    "wind": {
#       "speed": 5.05,
#       "deg": 216,
#       "gust": 4.05
#    },
#    "clouds": {
#       "all": 0
#    },
#    "dt": 1780471692,
#    "sys": {
#       "country": "IN",
#       "sunrise": 1780446919,
#       "sunset": 1780495052
#    },
#    "timezone": 19800,
#    "id": 1268773,
#    "name": "J\u016bn\u0101gadh",
#    "cod": 200
# }

# %%
print(result['main']['temp'])
# Out:
# 310.34

# %%
url4=f"https://api.openweathermap.org/data/2.5/forecast?lat={lat}&lon={lon}&appid={API_keys}"
response=requests.get(url4)
print(response.status_code)
result=response.json()
print(json.dumps(result,indent=5))
# Out:
# 200
# {
#      "cod": "200",
#      "message": 0,
#      "cnt": 40,
#      "list": [
#           {
#                "dt": 1780477200,
#                "main": {
#                     "temp": 310.86,
#                     "feels_like": 315.06,
#                     "temp_min": 310.86,
#                     "temp_max": 310.86,
#                     "pressure": 1003,
#                     "sea_level": 1003,
#                     "grnd_level": 992,
#                     "humidity": 38,
#                     "temp_kf": 0
#                },
#                "weather": [
#                     {
#                          "id": 800,
#                          "main": "Clear",
#                          "description": "clear sky",
#                          "icon": "01d"
#                     }
#                ],
#                "clouds": {
#                     "all": 5
#                },
#                "wind": {
#                     "speed": 8.02,
#                     "deg": 235,
# ...

# %%
print(result['list'][1]['main']['temp'])
# Out:
# 309.72
